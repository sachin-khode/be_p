# %% [markdown]
# # <font color=orangered>Detailed Report for data cleaning:

# %% [markdown]
# #### 1.) Given Data has 97 rows and 14 columns initialy<br>2.)With the help of heatmap null values observed <ol> - In column "Unnamed:10" all values observed null <ol></ol>

# %% [markdown]
# #### Treated 'Rank' column<br><ol> 1.)duplicate values were present</ol> <ol>2.)analysed more with each column and corrected</ol>

# %%
# df.info()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('/home/sk-ji/Cont_ent/Lending_Data/Lending Data.xlsx')
df.head()
# Out:
#   Name of Lending Institution HQ State Rank TA Ratio1 TBL Ratio1  \
# 0                         NaN      NaN   -1        -2         -3
# 1       American Express Co.       NY     1   0.23829   0.999544
# 2    First Citizens Banchares      NC     2  0.187393    0.49083
# 3    Wintrust Financial Corp.      IL     3  0.168999   0.383561
# 4               Zions Bancorp      UT     4  0.117973   0.260577
#
#   Amount ($1,000)  Number      Lender Asset Size  Amount ($1,000).1  \
# 0              -4       -5                    -6               -7.0
# 1        16350038  3603226  >$50B                        16318089.0
# 2         3914507   117702  $10B-$50B                      378394.0
# 3         2842793   136801  $10B-$50B                      800526.0
# 4         6231770    52612  >$50B                          526206.0
#
#    Number .1  Unnamed: 10  Amount ($1,000).2  Number .2 CC Amount/TA1
# 0       -8.0          NaN               -9.0      -10.0           -11
# ...

# %% [markdown]
# ## Given dataframe is having 97 rows <br> By analysing below graph we can see most of the null values are present in "Unnamed" column <br> Further, there are not huge amount of null values are present

# %%
sns.heatmap(df.isnull())

# %%
df.isnull().sum()  #very minor null values are present
# Out:
# Name of Lending Institution     1
# HQ State                        4
# Rank                            3
# TA Ratio1                       3
# TBL Ratio1                      3
# Amount ($1,000)                 3
# Number                          3
# Lender Asset Size               3
# Amount ($1,000).1               3
# Number .1                       3
# Unnamed: 10                    97
# Amount ($1,000).2               3
# Number .2                       3
# CC Amount/TA1                   3
# dtype: int64

# %% [markdown]
# ## Treating 'Rank' column<br><ol> duplicate values are present</ol> <ol>analysing more with each column</ol>

# %%
df.Rank = pd.to_numeric(df['Rank'],errors='coerce')

# %%
df.loc[df.duplicated(subset = 'Rank',keep=False),['Rank','Name of Lending Institution']]
# Out:
#     Rank                        Name of Lending Institution
# 8    8.0                        Capital One Financial Corp.
# 9    8.0                            Fulton Financial Corp.
# 11  11.0                                       U S Bancorp.
# 12  11.0                      First Niagara Financial Grp.
# 13  13.0                                   Lauritzen Corp.
# 14  13.0                         Huntington Bancshares Inc.
# 19  19.0                                         Citigroup
# 20  19.0                                           Popular
# 21  19.0                            Hancock Holding Company
# 34  34.0                           First Horizon Nat Corp.
# 35  34.0                               Commerce Bancshares
# 40  40.0                                           Keycorp
# 41  40.0                              Prosperity Bancshares
# 67  67.0                                     HSBC Bk USA NA
# 68  67.0                    Washington Fed.
# ...

# %%
df.loc[df.duplicated(subset = 'Rank',keep=False)]
# Out:
#                           Name of Lending Institution HQ State  Rank  \
# 8                         Capital One Financial Corp.      VA    8.0
# 9                             Fulton Financial Corp.       PA    8.0
# 11                                       U S Bancorp.      MN   11.0
# 12                      First Niagara Financial Grp.       NY   11.0
# 13                                   Lauritzen Corp.       NE   13.0
# 14                         Huntington Bancshares Inc.      OH   13.0
# 19                                         Citigroup       NY   19.0
# 20                                           Popular       PR   19.0
# 21                            Hancock Holding Company      MS   19.0
# 34                           First Horizon Nat Corp.       TN   34.0
# 35                               Commerce Bancshares       MO   34.0
# 40                                           Keycorp       OH   40.0
# 41                              Prosperity Bancshares      TX   40.0
# ...

# %% [markdown]
# ## Since we can see  in above dataframe that most of the rows in which the Rank is not present, are missing out most of the data in each column so we can remove the entire rows

# %%
df.drop(df.index[range(89,97)],inplace=True)
df.loc[df.duplicated(subset = 'Rank',keep=False)]
# Out:
#         Name of Lending Institution HQ State  Rank   TA Ratio1 TBL Ratio1  \
# 8       Capital One Financial Corp.      VA    8.0   0.0275597   0.316466
# 9           Fulton Financial Corp.       PA    8.0    0.129126   0.347611
# 11                     U S Bancorp.      MN   11.0    0.042109   0.204845
# 12    First Niagara Financial Grp.       NY   11.0   0.0721729   0.287846
# 13                 Lauritzen Corp.       NE   13.0   0.0705079   0.337212
# 14       Huntington Bancshares Inc.      OH   13.0   0.0693833   0.222013
# 19                       Citigroup       NY   19.0   0.0125174   0.262057
# 20                         Popular       PR   19.0   0.0708661   0.257545
# 21          Hancock Holding Company      MS   19.0   0.0923077   0.298702
# 34         First Horizon Nat Corp.       TN   34.0   0.0520809   0.212716
# 35             Commerce Bancshares       MO   34.0    0.051393   0.267501
# 40                         Keycorp       OH   40.0   0.0384156   0.139378
# ...

# %%
df.shape
# Out:
# (89, 14)

# %% [markdown]
# ## After treating dataframe shape got reduced from 97 to 89 <br> <ol>- Now treating 'Unnamed:10' column since its all values are null we can drop this column </ol>

# %%
df['Unnamed: 10'].isnull().sum()
# Out:
# 89

# %%
df.drop('Unnamed: 10',inplace=True,axis=1)

# %% [markdown]
# ## <font color=teal >current shape of Dataframe is now

# %%
df.shape
# Out:
# (89, 13)

# %%
df.isnull().sum()
# Out:
# Name of Lending Institution    1
# HQ State                       1
# Rank                           0
# TA Ratio1                      0
# TBL Ratio1                     0
# Amount ($1,000)                0
# Number                         0
# Lender Asset Size              0
# Amount ($1,000).1              0
# Number .1                      0
# Amount ($1,000).2              0
# Number .2                      0
# CC Amount/TA1                  0
# dtype: int64

# %% [markdown]
# ## Analysing lending Asset size

# %%
df['Lender Asset Size'].describe()
# Out:
# count                       89
# unique                       4
# top       $10B-$50B
# freq                        43
# Name: Lender Asset Size, dtype: object

# %%
# from sklearn.preprocessing import LabelEncoder
# encoder = LabelEncoder()
# # df["encoded_lender_asset_size"] = encoder.fit_transform(df["Lender Asset Size"])
# df.head()

# %%
# df["encoded_lender_asset_size"] = encoder.fit_transform(df["Lender Asset Size"].astype(str))

# %%
# df[['Lender Asset Size','encoded_lender_asset_size']].h

# %%
df = df.drop(0)

# %%
df.columns
# Out:
# Index(['Name of Lending Institution', 'HQ State', 'Rank', 'TA Ratio1',
#        'TBL Ratio1', 'Amount ($1,000)', 'Number ', 'Lender Asset Size',
#        'Amount ($1,000).1', 'Number .1', 'Amount ($1,000).2', 'Number .2',
#        'CC Amount/TA1'],
#       dtype='object')

# %%
df
# Out:
#        Name of Lending Institution HQ State  Rank    TA Ratio1   TBL Ratio1  \
# 1            American Express Co.       NY    1.0      0.23829     0.999544
# 2         First Citizens Banchares      NC    2.0     0.187393      0.49083
# 3         Wintrust Financial Corp.      IL    3.0     0.168999     0.383561
# 4                    Zions Bancorp      UT    4.0     0.117973     0.260577
# 5          Synovus Financial Corp.      GA    5.0     0.162333     0.381387
# ..                             ...      ...   ...          ...          ...
# 84  Flagstar Bk FSB                      MI  84.0   0.00655517     0.069132
# 85    Onewest Bk FSB                     CA  85.0   0.00433395    0.0500412
# 86        Bank of NY Mellon Corp.       NY   86.0  0.000310486    0.0480148
# 87        Goldman Sachs Group The       NY   87.0  3.48757e-05   0.00102276
# 88        Deutsche Bk Tc Americas       NY   88.0  4.67874e-05  0.000333249
#
# ...

# %%
df['Lender Asset Size'] = df['Lender Asset Size'].replace({'>$50B               ':1, '$10B-$50B':2, '>$10B':3}, inplace=True)

# %%
df['Lender Asset Size'].unique()
# Out:
# array([None], dtype=object)
